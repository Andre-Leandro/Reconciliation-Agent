# %%
import pandas as pd
import numpy as np


# 1. CONFIGURACION INICIAL
ARCHIVO_SAP = 'SAP Exports/DEC 2025.xlsx' 
ARCHIVO_BANCARIO = 'EB_11137480.xlsx'
CUENTA_OBJETIVO = '11137480'
MES_NOMBRE = "December" 
MES_NUMERO = "012" 
ANIO = "2025"
DIRECCION = 'prueba/Master'
DEBUG = True

COLUMNAS_SALIDA = [
    'G/L Account', 'Journal Entry', 'Company Code', 'Journal Entry Type', 'Posting Date', 
    'Amount in Company Code Currency', 'Journal Entry Item Text', 'Description',
    'Value date', 'Amount in Transaction Currency', 
    'Offsetting Account', 'Amount in Global Currency', 'Assignment Reference', 
    'Clearing Date', 'Journal Entry Item', 'Fiscal Period', 'Clearing Journal Entry',
    'G/L Account Long Name', 'G/L Account Name',
]

reglas_entidades = {
    'Hoja 1': { 
        'prefix': 'Tep', 
        'xq_ba': [r'AJ.?2248', r'BA.?0008'], 
        'bank_text': [r'CREDIT MEMO', r'PAYMASTER'] 
    },
}

# 2. PROCESAMIENTO

df_original = pd.read_excel(ARCHIVO_SAP)
eb = pd.read_excel(ARCHIVO_BANCARIO)

def clean_amount(val):
    if pd.isna(val): return 0.0
    if isinstance(val, (int, float)): return float(val)
    val = str(val).replace('JMD', '').replace('USD', '').replace(',', '').strip()
    try: return float(val)
    except: return 0.0

def build_desc_lookup(df_bank):
    desc_col = 'DESCRIPTION'
    debits_col = 'DEBITS'
    credits_col = 'CREDITS'
    if desc_col not in df_bank.columns or (debits_col not in df_bank.columns and credits_col not in df_bank.columns):
        return pd.Series(dtype='object')
    parts = []
    if debits_col in df_bank.columns:
        deb = df_bank[[debits_col, desc_col]].copy()
        deb['amount_match'] = deb[debits_col].apply(clean_amount).abs()
        parts.append(deb[['amount_match', desc_col]])
    if credits_col in df_bank.columns:
        cred = df_bank[[credits_col, desc_col]].copy()
        cred['amount_match'] = cred[credits_col].apply(clean_amount).abs()
        parts.append(cred[['amount_match', desc_col]])
    if not parts:
        return pd.Series(dtype='object')
    eb_long = pd.concat(parts, ignore_index=True)
    eb_long = eb_long[eb_long['amount_match'] != 0]
    eb_long = eb_long.dropna(subset=[desc_col])
    return eb_long.groupby('amount_match')[desc_col].first()

# Formato de fecha Dia/Mes/Ano con barras
def clean_date(val):
    if pd.isna(val) or val == "" or str(val).lower() == "nan": return ""
    try:
        return pd.to_datetime(val).strftime('%d/%m/%Y')
    except:
        return str(val)

cols_monto = ['Amount in Transaction Currency', 'Amount in Global Currency', 'Amount in Company Code Currency']
for col in cols_monto:
    if col in df_original.columns:
        df_original[col] = df_original[col].apply(clean_amount)

# Match por monto absoluto contra Debits/Credits del extracto
desc_lookup = build_desc_lookup(eb)

df_original['Description'] = df_original['Amount in Transaction Currency'].abs().map(desc_lookup).fillna("")

df_acc = df_original[df_original['G/L Account'].astype(str).str.contains(CUENTA_OBJETIVO, na=False)].copy()

if DEBUG:
    print("--- DEBUG Description ---")
    print("Filas df_acc:", len(df_acc))
    print("Description vacio:", (df_acc['Description'] == "").sum())
    print("Description no vacio:", (df_acc['Description'] != "").sum())
    print(df_acc['Description'].value_counts().head(10))
    bank_pat = '|'.join(reglas_entidades['Hoja 1']['bank_text'])
    mask_desc = df_acc['Description'].str.contains(bank_pat, na=False, regex=True, case=False)
    print("Matches Description (sin Journal Entry Type):", mask_desc.sum())
    print(df_acc.loc[mask_desc, ['Journal Entry Type', 'Description']].head(10))

output_file = f'{DIRECCION}_{CUENTA_OBJETIVO}_{MES_NOMBRE}_{ANIO}.xlsx'
writer = pd.ExcelWriter(output_file, engine='xlsxwriter')

workbook = writer.book
fmt_jam = workbook.add_format({'num_format': '#,##0.00 "JMD"'}) 
fmt_usd = workbook.add_format({'num_format': '#,##0.00 "USD"'}) 
fmt_std = workbook.add_format({'num_format': '#,##0.00'})

for entidad, reglas in reglas_entidades.items():
    condicion_xq = (df_acc['Journal Entry Type'].str.contains('XQ', na=False, case=False)) & \
                   (df_acc['Journal Entry Item Text'].str.contains('|'.join(reglas['xq_ba']), na=False, regex=True, case=False))
    df_xq = df_acc[condicion_xq].copy()
    
    condicion_bank = (df_acc['Journal Entry Type'].str.contains('ZB|ZR|BR|IB', na=False, case=False)) & \
                     (df_acc['Description'].str.contains('|'.join(reglas['bank_text']), na=False, regex=True, case=False))
    df_bank = df_acc[condicion_bank].copy()
    
    if DEBUG:
        print("--- DEBUG Bank Filter ---")
        print("Matches Journal Entry Type:", df_acc['Journal Entry Type'].str.contains('ZB|ZR|BR|IB', na=False, case=False).sum())
        print("Matches Description:", df_acc['Description'].str.contains('|'.join(reglas['bank_text']), na=False, regex=True, case=False).sum())
        print("Matches BOTH:", condicion_bank.sum())
    
    total_xq = df_xq['Amount in Transaction Currency'].sum()
    total_bank = df_bank['Amount in Transaction Currency'].sum()
    diferencia = total_xq + total_bank
    nom_text = f"{reglas['prefix']} Lib{abs(total_xq):.2f} BK{abs(total_bank):.2f} - {MES_NOMBRE} {ANIO}"
    
    filas_finales = df_xq.to_dict('records')
    filas_finales.append({}) 
    filas_finales.append({'Amount in Transaction Currency': total_xq})
    filas_finales.append({}) 
    
    filas_finales.extend(df_bank.to_dict('records'))
    filas_finales.append({}) 
    filas_finales.append({'Amount in Transaction Currency': total_bank})
    filas_finales.append({}) 
    filas_finales.append({
        'Amount in Transaction Currency': diferencia, 
        'Offsetting Account': nom_text 
    })
    
    df_sheet = pd.DataFrame(filas_finales)

    # Logica para limpiar Fiscal Period y Company Code Currency en totales/vacios
    def is_real_data(row):
        gl_val = str(row.get('G/L Account', ''))
        return pd.notna(row.get('G/L Account')) and gl_val != "" and gl_val.lower() != "nan"

    if 'Amount in Transaction Currency' in df_sheet.columns:
        # Solo poner JMD y 002 si hay una cuenta contable real en esa fila
        df_sheet['Amount in Company Code Currency'] = df_sheet.apply(
            lambda x: x['Amount in Transaction Currency'] if is_real_data(x) else "", 
            axis=1
        )
        df_sheet['Fiscal Period'] = df_sheet.apply(
            lambda x: MES_NUMERO if is_real_data(x) else "", 
            axis=1
        )
    
    # Formatear fechas Dia/Mes/Ano
    for date_col in ['Posting Date', 'Value date', 'Clearing Date']:
        if date_col in df_sheet.columns:
            df_sheet[date_col] = df_sheet[date_col].apply(clean_date)
            
    for col in COLUMNAS_SALIDA:
        if col not in df_sheet.columns: df_sheet[col] = ""
    df_sheet = df_sheet[COLUMNAS_SALIDA]
    
    df_sheet.to_excel(writer, sheet_name=entidad, index=False)
    
    worksheet = writer.sheets[entidad]
    for i, col in enumerate(df_sheet.columns):
        max_len = max(df_sheet[col].astype(str).map(len).max(), len(col)) + 1
        
        if col in ['Amount in Transaction Currency', 'Amount in Company Code Currency']:
            worksheet.set_column(i, i, max_len, fmt_jam)
        elif col == 'Amount in Global Currency':
            worksheet.set_column(i, i, max_len, fmt_usd)
        elif 'Amount' in col:
            worksheet.set_column(i, i, max_len, fmt_std)
        else:
            worksheet.set_column(i, i, max_len)

writer.close()
print(f"Reporte Maestro Correcto Generado: {output_file}")
# Out:
# --- DEBUG Description ---
# Filas df_acc: 287
# Description vacio: 115
# Description no vacio: 172
# Description
#                                                                                                                   115
# SWEEP STANDING ORDER CREDIT\nTransfer From 50765 720911                                                            43
# SWEEP STANDING ORDER CREDIT\nTransfer From 50765 37516                                                             42
# SWEEP STANDING ORDER CREDIT\nTransfer From 50765 69116                                                             42
# ELECTRONIC CREDIT\n757847958 ISLAND NETWORKS CREDIT\n075DCOO253381010*                                             20
# SCOTIA DIRECT CREDIT\nNov 2025 Intercon.and JS VERGE\nCOMMUNICAT Dec 2025\nNov 2025 Intercon.and JS pmt.            3
# SCOTIA DIRECT CREDIT\nInv. CN Oct-25, C010818, UBITELECOM\nLIMIT Cable & Wi\nInv. CN Oct-25, C010818, 90030131      3
# SCOTIA DIRECT CREDIT\nInterconnect and JS Oct 2 VERGE\nCOMMUNICAT Dec 2025\nInterconnect and JS Oct 2025.           3
# SCOTIA DIRECT CREDIT\nInv. CN Nov-25 C010825 UBITELECOM\nLIMIT Cable\nInv. CN Nov-25 C010825                        2
# INTEREST PAYMENT                                                                                                    2
# Name: count, dtype: int64
# Matches Description (sin Journal Entry Type): 9
#              Journal Entry Type                                  Description
# 2143  ZB (Bank Stat Electronic)  CREDIT MEMO\nRTGS 251202N059563C00 PAYMASTE
# 2559  ZB (Bank Stat Electronic)  CREDIT MEMO\nRTGS 251203N075048C00 PAYMASTE
# 2950  ZB (Bank Stat Electronic)  CREDIT MEMO\nRTGS 251204N083573C00 PAYMASTE
# 3449  ZB (Bank Stat Electronic)  CREDIT MEMO\nRTGS 251205N094675C00 PAYMASTE
# 6546  ZB (Bank Stat Electronic)  CREDIT MEMO\nRTGS 251208N022494C00 PAYMASTE
# 6554  ZB (Bank Stat Electronic)  CREDIT MEMO\nRTGS 251209N032324C00 PAYMASTE
# 6976  ZB (Bank Stat Electronic)  CREDIT MEMO\nRTGS 251210N045549C00 PAYMASTE
# 7352  ZB (Bank Stat Electronic)  CREDIT MEMO\nRTGS 251211N054992C00 PAYMASTE
# 9481  ZB (Bank Stat Electronic)           CREDIT MEMO\nRTGS 251212N065743C00
# --- DEBUG Bank Filter ---
# Matches Journal Entry Type: 154
# Matches Description: 9
# Matches BOTH: 9
# Reporte Maestro Correcto Generado: prueba/Master_11137480_December_2025.xlsx

# %%
df_bank.head()
# Out:
# Empty DataFrame
# Columns: [Company Code, G/L Account, Journal Entry Type, Posting Key, Journal Entry, Journal Entry Item Text, Posting Date, Value date, Amount in Transaction Currency, Amount in Global Currency, Offsetting Account, Profit Center, Assignment Reference, Clearing Date, G/L Account Name, Clearing Journal Entry, Description]
# Index: []

# %%
eb = pd.read_excel('Extracto_Bancario_Limpio.xlsx')
eb.head()
# Out:
#          DATE      TRANSACTION TYPE  \
# 0  12/01/2025      GENERAL DEPOSITS
# 1  12/01/2025         SCOTIA DIRECT
# 2  12/01/2025  GENERAL\nWITHDRAWALS
# 3  12/01/2025       STANDING ORDERS
# 4  12/01/2025       STANDING ORDERS
#
#                                          DESCRIPTION      DEBITS     CREDITS  \
# 0        RTGS CREDIT\nFT25332B8287,SUPREMEVENTURESFI         NaN  327,589.57
# 1  SCOTIA DIRECT CREDIT\nTRANSACTIONS E-P Columbus C         NaN  126,190.00
# 2                      CREDIT MEMO\nRTGS 32950TEA9OU         NaN   50,051.75
# 3  SWEEP STANDING ORDER DEBIT\nTransfer To 50765 ...  432,815.66         NaN
# 4  SWEEP STANDING ORDER DEBIT\nTransfer To 50765 ...   64,922.35         NaN
#
#       BALANCE
# 0  332,953.15
# 1  459,143.15
# 2  509,194.90
# 3   76,379.24
# 4   11,456.89

# %%
df_original.head()
# Out:
#                   Company Code                                  G/L Account  \
# 0  JM10 (Cable & Wireless Jam)    11137599 (Scotia Collections Fx Adj 0128)
# 1  JM10 (Cable & Wireless Jam)    11137599 (Scotia Collections Fx Adj 0128)
# 2  JM10 (Cable & Wireless Jam)    11137599 (Scotia Collections Fx Adj 0128)
# 3  JM10 (Cable & Wireless Jam)    11137599 (Scotia Collections Fx Adj 0128)
# 4  JM10 (Cable & Wireless Jam)  11137699 (Citibank Collections Fx Adj 9136)
#
#   Journal Entry Type  Posting Key  Journal Entry  \
# 0  FX (FX Valuation)           50      210173886
# 1  FX (FX Valuation)           40      210173888
# 2  FX (FX Valuation)           50      210173890
# 3  FX (FX Valuation)           40      210173890
# 4  FX (FX Valuation)           50      210173892
#
#                      Journal Entry Item Text Posting Date Value date  \
# 0  11137500 - Valuation on 20251130 Reversal   2025-12-01        NaT
# 1  11137520 - Valuation on 20251130 Reversal   2025-12-01        NaT
# 2  11137580 - Valuation on 20251130 Reversal   2025-12-01        NaT
# 3  11137580 - Valuation on 20251130 Reversal   2025-12-01        NaT
# 4  11137600 - Valuation on 20251130 Reversal   2025-12-01        NaT
#
#    Amount in Transaction Currency  Amount in Global Currency  \
# 0                             0.0                  -61226.56
# 1                             0.0                    6741.83
# 2                             0.0                   -2689.09
# 3                             0.0                    1404.01
# 4                             0.0                 -173205.83
#
#               Offsetting Account           Profit Center Assignment Reference  \
# 0  72010150 (Unrealized FX Cash)  82400001 (Unallocated)                  NaN
# 1  72010150 (Unrealized FX Cash)  82400001 (Unallocated)                  NaN
# 2  72010150 (Unrealized FX Cash)  82400001 (Unallocated)                  NaN
# 3     11137599 (BNS FX Adj 0128)  82400001 (Unallocated)                  NaN
# 4  72010150 (Unrealized FX Cash)  82400001 (Unallocated)                  NaN
#
#   Clearing Date  G/L Account Name  Clearing Journal Entry Description
# 0           NaT   BNS FX Adj 0128                     NaN
# 1           NaT   BNS FX Adj 0128                     NaN
# 2           NaT   BNS FX Adj 0128                     NaN
# 3           NaT   BNS FX Adj 0128                     NaN
# 4           NaT  Citi FX Adj 9136                     NaN

# %%
df_original.Description.value_counts()
# Out:
# Description
#                                                                               43246
# SWEEP STANDING ORDER DEBIT\nTransfer To 50765 380911                            170
# CREDIT MEMO\nRTGS 1637631230202500000000000                                      65
# SCOTIA DIRECT CREDIT\nTRANSACTIONS E-P Columbus C                                50
# CREDIT MEMO\nRTGS 1637631224202500000000000                                       7
# CREDIT MEMO\nRTGS 1637631201202500 The Vict                                       4
# WITHHOLDING TAX                                                                   4
# RTGS CREDIT\n1637631204202500,The Victoria                                        4
# CREDIT MEMO\nRTGS 1637631222202500000000000                                       3
# FUNDS TRANSFER FROM\nSUPREMEVENTURESFINTECHLIMITED\nSAJAJMKN\nFT25353W1Y9P        3
# FUNDS TRANSFER FROM\nSUPREMEVENTURESFINTECHLIMITED\nSAJAJMKN\nFT253500LJYK        3
# FUNDS TRANSFER FROM\nSUPREMEVENTURESFINTECHLIMITED\nSAJAJMKN\nFT25352DMXZB        3
# FUNDS TRANSFER FROM\nSUPREMEVENTURESFINTECHLIMITED\nSAJAJMKN\nFT25351Q95JT        3
# CREDIT MEMO\nRTGS 35050U7IAMC The Victo                                           3
# FUNDS TRANSFER FROM\nSUPREMEVENTURESFINTECHLIMITED\nSAJAJMKN\nFT253657THLL        3
# INTEREST PAYMENT                                                                  3
# FUNDS TRANSFER FROM\n779005088 REMOTE HOLDINGS ADMIN\nOct. 6 - 7, 2025            3
# CREDIT MEMO\nRTGS 35150U9JZ3O The Victo                                           2
# FUNDS TRANSFER FROM\n779005252 REMOTE HOLDINGS ADMIN\nOct. 13 - 14, 2025          2
# FUNDS TRANSFER FROM\n779005253 REMOTE HOLDINGS ADMIN\nOct. 17 - 19, 2025          2
# FUNDS TRANSFER FROM\n779005089 REMOTE HOLDINGS ADMIN\nOctober 10 - 12, 202        2
# FUNDS TRANSFER FROM\n779005090 REMOTE HOLDINGS ADMIN\nOctober 8 - 9, 2025         2
# FUNDS TRANSFER FROM\n779005255 REMOTE HOLDINGS ADMIN\nOct. 15 - 16, 2025          2
# FUNDS TRANSFER FROM\nSUPREMEVENTURESFINTECHLIMITED\nSAJAJMKN\nFT253568NM2V        2
# FUNDS TRANSFER FROM\nSUPREMEVENTURESFINTECHLIMITED\nSAJAJMKN\nFT25357DR81S        2
# FUNDS TRANSFER FROM\nSUPREMEVENTURESFINTECHLIMITED\nSAJAJMKN\nFT2535806BVP        2
# FUNDS TRANSFER FROM\nSUPREMEVENTURESFINTECHLIMITED\nSAJAJMKN\nFT25364QWYYZ        2
# FUNDS TRANSFER FROM\nSUPREMEVENTURESFINTECHLIMITED\nSAJAJMKN\nFT25363PX6JV        2
# CREDIT MEMO\nRTGS 34650U38X63 The Victo                                           2
# FUNDS TRANSFER FROM\nSUPREMEVENTURESFINTECHLIMITED\nSAJAJMKN\nFT25346V6SRP        2
# FUNDS TRANSFER FROM\nSUPREMEVENTURESFINTECHLIMITED\nSAJAJMKN\nFT253494LJ0R        2
# RTGS CREDIT\n1637631205202500,The Victoria                                        2
# CREDIT MEMO\nRTGS 32950TEA9OU                                                     2
# RTGS CREDIT\nFT253355KQ06,SUPREMEVENTURESFI                                       2
# RTGS CREDIT\nFT253364KR5X,SUPREMEVENTURESFI                                       2
# RTGS CREDIT\n1637631201202500,The Victoria                                        2
# FUNDS TRANSFER FROM\n777821367 REMOTE HOLDINGS ADMIN\nSept 24-25 2025             2
# RTGS CREDIT\n251204N085496C00,REMOTE HOLDIN                                       2
# FUNDS TRANSFER FROM\n777825304 REMOTE HOLDINGS ADMIN\nOct 3 - 5 2025              2
# FUNDS TRANSFER FROM\n777825303 REMOTE HOLDINGS ADMIN\nOct 1 - 2 2025              2
# CREDIT MEMO\nRTGS 34550U16YIO The Vict                                            2
# FUNDS TRANSFER FROM\n777821515 REMOTE HOLDINGS ADMIN\nSept 29 -30 2025            2
# RTGS CREDIT\nFT253387T7J7,SUPREMEVENTURESFI                                       2
# RTGS CREDIT\nFT253426Q4CY,SUPREMEVENTURESFI                                       2
# DEPOSIT\nFT25342G4S4C,SUPREMEVENTURESFI                                           2
# RTGS CREDIT\n1637631209202500,The Victoria                                        2
# RTGS CREDIT\n1637631208202500,The Victoria                                        2
# RTGS CREDIT\nFT253441CHH0,SUPREMEVENTURESFI                                       2
# RTGS CREDIT\nFT25343WSJXR,SUPREMEVENTURESFI                                       2
# RTGS CREDIT\nFT25345KGBF5,SUPREMEVENTURESFI                                       2
# RTGS CREDIT\n1637631210202500,The Victoria                                        2
# RTGS CREDIT\nFT25332B8287,SUPREMEVENTURESFI                                       2
# SERVICE CHARGE\nFor 31DEC25                                                       1
# GCT/GOVT TAX\nON SERVICE CHARGE OF 158.80                                         1
# Name: count, dtype: int64
